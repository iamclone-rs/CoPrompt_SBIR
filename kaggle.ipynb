# %%
# !git clone https://github.com/iamclone-rs/CoPrompt_SBIR
# Out:
# Cloning into 'CoPrompt_SBIR'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 46 (delta 3), reused 46 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 17.00 MiB | 84.08 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# !pip uninstall -y pytorch-lightning torchmetrics lightning-fabric lightning-utilities || true
# Out:
# Found existing installation: pytorch-lightning 2.6.0
# Uninstalling pytorch-lightning-2.6.0:
#   Successfully uninstalled pytorch-lightning-2.6.0
# Found existing installation: torchmetrics 1.8.2
# Uninstalling torchmetrics-1.8.2:
#   Successfully uninstalled torchmetrics-1.8.2
# WARNING: Skipping lightning-fabric as it is not installed.
# Found existing installation: lightning-utilities 0.15.2
# Uninstalling lightning-utilities-0.15.2:
#   Successfully uninstalled lightning-utilities-0.15.2

# %%
# !python -m pip install -U "pip<24.1"
# !pip --version
# !pip install pytorch-lightning==1.7.3 torchmetrics==0.9.3
# Out:
# ...
# pip 24.0 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# ...
#   Using cached pytorch_lightning-1.7.3-py3-none-any.whl.metadata (27 kB)
# ...
#   Using cached torchmetrics-0.9.3-py3-none-any.whl.metadata (17 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.8/705.8 kB 25.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.6/419.6 kB 34.3 MB/s eta 0:00:00
# ...
# DEPRECATION: pytorch-lightning 1.7.3 has a non-standard dependency specifier torch>=1.9.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...

# %%
# !pip install -q  ftfy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.9 MB/s eta 0:00:00
# DEPRECATION: pytorch-lightning 1.7.3 has a non-standard dependency specifier torch>=1.9.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
cd CoPrompt_SBIR
# Out:
# [Errno 2] No such file or directory: 'CoPrompt_SBIR'
# /kaggle/working/CoPrompt_SBIR

# %%
# !pip install -U "numpy<2"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 114.5 MB/s eta 0:00:0000:0100:01
# DEPRECATION: pytorch-lightning 1.7.3 has a non-standard dependency specifier torch>=1.9.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# ...

# %%
# !python -m experiments.LN_prompt --exp_name=LN_prompt --n_prompts=3 --clip_LN_lr=1e-6 --prompt_lr=1e-4 --batch_size=192 --workers=24 --data_dir /kaggle/input/sketchy
# Out:
# 2026-02-03 04:54:51.156647: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770094491.171417     599 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770094491.175677     599 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770094491.185969     599 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
